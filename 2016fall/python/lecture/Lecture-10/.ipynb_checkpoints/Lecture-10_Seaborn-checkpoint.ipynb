# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
np.random.seed(sum(map(ord, "aesthetics")))

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %%
sinplot()

# %%
import seaborn as sns
sinplot()

# %% [markdown]
# ## Styling figures with axes_style() and set_style()

# %%
np.random.normal(size=(20, 6))[:2]
# Out:
# array([[-1.50025307, -0.67201927, -2.10532584,  0.24387956,  0.9156214 ,
#         -0.66122127],
#        [ 0.31593546,  0.55365631,  1.40190228, -2.9009618 ,  0.56879796,
#         -0.40975573]])

# %%
np.arange(6) / 2
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5])

# %%
sns.set_style("whitegrid")
data = np.random.normal(size=(20, 6)) + np.arange(6) / 2
data[:2]
# Out:
# array([[-0.5585246 ,  1.22139556,  0.51527738,  1.38208626,  1.60089697,
#          1.46071605],
#        [ 0.77866858,  1.86605306,  0.17220622,  2.75964124,  2.49884138,
#          3.50711376]])

# %%
sns.boxplot(data=data)

# %%
sns.set_style("dark")  # sns.set_style("white")
sinplot()

# %%
sns.set_style("ticks")
sinplot()

# %%
sinplot()
sns.despine()

# %%
sinplot()
sns.despine(left=True)

# %%
with sns.axes_style("darkgrid"):
    plt.subplot(211)
    sinplot()
plt.subplot(212)
sinplot(-1)

# %% [markdown]
# ## Choosing color palettes

# %%
# www.xkcd.com to find more colors

# %%
current_palette = sns.color_palette()
sns.palplot(current_palette)

# %%
sns.palplot(sns.color_palette("hls", 8))

# %%
sns.palplot(sns.color_palette("Paired"))

# %%
sns.palplot(sns.color_palette("Set2", 10))

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
sns.palplot(sns.color_palette(flatui))

# %%
colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple"]
sns.palplot(sns.xkcd_palette(colors))

# %%
sns.palplot(sns.color_palette("Blues"))

# %%
sns.palplot(sns.color_palette("BuGn_r"))   # Reverse lightness ramp

# %%
sns.palplot(sns.color_palette("GnBu_d"))   # Dark Palettes

# %%
sns.palplot(sns.cubehelix_palette(8))

# %%
sns.palplot(sns.cubehelix_palette(8, start=.5, rot=-.75))

# %%
sns.palplot(sns.light_palette("green"))
# sns.palplot(sns.dark_palette("purple"))
# sns.palplot(sns.light_palette("navy", reverse=True))

# %%
sns.palplot(sns.color_palette("BrBG", 7))

# %%
sns.palplot(sns.color_palette("RdBu_r", 7))

# %%
sns.set_palette("husl")
sinplot()

# %%
sns.set_palette(sns.xkcd_palette(colors))
sinplot()

# %% [markdown]
# ## FactorPlots

# %%
exercise = sns.load_dataset("exercise")
exercise.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
g = sns.factorplot(x="time", y="pulse", hue="kind", data=exercise)

# %%
g = sns.factorplot(x="time", y="pulse", hue="kind",
                    col="diet", data=exercise)

# %% [markdown]
# ## Box Plot

# %%
sns.set_style("whitegrid")
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax = sns.boxplot(x=tips["total_bill"])

# %%
ax = sns.boxplot(x="day", y="total_bill", data=tips)

# %%
ax = sns.boxplot(x="day", y="total_bill", hue="smoker",
                  data=tips, palette="Set3")

# %%
ax = sns.boxplot(x="day", y="total_bill", hue="time",
                  data=tips, linewidth=2.5)

# %%
ax = sns.boxplot(x="time", y="tip", data=tips,
                  order=["Dinner", "Lunch"])

# %%
iris = sns.load_dataset("iris")
ax = sns.boxplot(data=iris, orient="h", palette="Set2")

# %%
tips = sns.load_dataset("tips")
ax = sns.pointplot(x="time", y="total_bill", data=tips)  # color="#bb3f3f"

# %%
ax = sns.pointplot(x="time", y="total_bill", hue="smoker",
                    data=tips)

# %%
ax = sns.pointplot(x="time", y="total_bill", hue="smoker",
                    data=tips,
                    markers=["o", "x"],
                    linestyles=["-", "--"])

# %%
ax = sns.pointplot(x="time", y="total_bill", hue="smoker",
                    data=tips, palette="Set2")

# %%
ax = sns.barplot(x="day", y="total_bill", data=tips)

# %%
ax = sns.barplot(x="day", y="total_bill", hue="sex", data=tips)

# %%
ax = sns.barplot("size", y="total_bill", data=tips,
                  palette="Blues_d")

# %%
ax = sns.barplot("day", "total_bill", data=tips,
                  linewidth=2.5, facecolor=(1, 1, 1, 0),
                  errcolor=".2", edgecolor=".2")

# %% [markdown]
# ## StripPlot

# %%
ax = sns.stripplot(x=tips["total_bill"])

# %%
ax = sns.stripplot(x="day", y="total_bill", data=tips)

# %%
ax = sns.stripplot(x="day", y="total_bill", data=tips, jitter=True)   # jitter=0.05

# %%
ax = sns.stripplot(x="sex", y="total_bill", hue="day",
                    data=tips, jitter=True)

# %%
ax = sns.stripplot(x="day", y="total_bill", hue="smoker",
                    data=tips, jitter=True,
                    palette="Set2", split=True)

# %%
ax = sns.boxplot(x="tip", y="day", data=tips, whis=np.inf)
ax = sns.stripplot(x="tip", y="day", data=tips,
                    jitter=True, color=".3")

# %%
import sys
import os
import datetime
from pandas import Series, DataFrame
import pandas as pd

path = '/Users/wuyan/Documents/courses/2016 fall/python/DataAnalysisPython/data/stock_data/data/stocks'

count = 0
for pos_csv in os.listdir(path):
    if count == 50:
        break
    if pos_csv.endswith('.csv'): 
        file = os.path.join(path, pos_csv)
        df = pd.read_csv(file)
        count += 1

# %%
import pandas as pd
from datetime import datetime, date, timedelta
from glob import glob

# %%
all_df=[]
for fi in glob('/Users/wuyan/Documents/courses/2016 fall/python/DataAnalysisPython/data/stock_data/data/stocks/*.csv'):
    df = pd.read_csv(fi)
    name = fi.split('/')[-1].split('.')[0]
    df['name']=name
    all_df.append(df)
f_df = pd.concat(all_df)

# %%
f_df.head()
# Out:
#    Adj Close      Close        Date       High        Low       Open  SPX  \
# 0  31.370001  31.370001  2015-08-07  31.629999  31.200001  31.480000  NaN
# 1  31.150000  31.150000  2015-08-06  31.290001  31.090000  31.260000  NaN
# 2  31.520000  31.520000  2015-08-05  31.860001  31.510000  31.690001  NaN
# 3  31.469999  31.469999  2015-08-04  31.840000  31.440001  31.440001  NaN
# 4  31.670000  31.670000  2015-08-03  31.750000  31.549999  31.670000  NaN
#
#   Unnamed: 0   Volume  name
# 0        NaN   1100.0  AAIT
# 1        NaN    600.0  AAIT
# 2        NaN  67400.0  AAIT
# 3        NaN   3700.0  AAIT
# 4        NaN   4000.0  AAIT

# %%
df_2015 = f_df[f_df['Date'].str.contains('2015')].reset_index(drop=True)

# %%
df_2015.tail()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-72e6e1fe2d40> in <module>()
# ----> 1 sns.set_style("whitegrid")
#       2 tips = sns.load_dataset("tips")
#       3 tips.head()
#
# NameError: name 'sns' is not defined

# %%
## AAIT Box Plot

# %%
#make background white
#every bar should have same color - windows blue
#make the year lable titled at 45 degrees
#change font size of ticks and labels to make them look big (dont use default font size)
#change the title
#make the limit of y axis to be (min(high) * 0.8, max(high) * 1.2)
#change your figure size to be (20, 8)
# add the annotation on the top of the plot showing the mean  ----

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from datetime import datetime, date
import time
# %matplotlib inline

# %%
df = pd.read_csv("/Users/wuyan/Documents/courses/2016 fall/python/DataAnalysisPython/data/stock_data/data/stocks/AAIT.csv")

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Volume  Adj Close
# 0  2015-08-07  31.480000  31.629999  31.200001  31.370001    1100  31.370001
# 1  2015-08-06  31.260000  31.290001  31.090000  31.150000     600  31.150000
# 2  2015-08-05  31.690001  31.860001  31.510000  31.520000   67400  31.520000
# 3  2015-08-04  31.440001  31.840000  31.440001  31.469999    3700  31.469999
# 4  2015-08-03  31.670000  31.750000  31.549999  31.670000    4000  31.670000

# %%
new_df = df[['Date', 'High']]

# %%
new_df['Date'] = new_df['Date'].apply(lambda x : datetime.strptime(x,'%Y-%m-%d').strftime('%Y'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-d6835d59db66> in <module>()
# ----> 1 new_df['Date'] = new_df['Date'].apply(lambda x : datetime.strptime(x,'%Y-%m-%d').strftime('%Y'))
#
# /Users/wuyan/anaconda/lib/python3.5/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2290             else:
#    2291                 values = self.asobject
# -> 2292                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2293
#    2294         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:63307)()
#
# <ipython-input-78-d6835d59db66> in <lambda>(x)
# ----> 1 new_df['Date'] = new_df['Date'].apply(lambda x : datetime.strptime(x,'%Y-%m-%d').strftime('%Y'))
#
# ...

# %%
new_df.loc[:, 'Date']
# Out:
# 0      2015
# 1      2015
# 2      2015
# 3      2015
# 4      2015
# 5      2015
# 6      2015
# 7      2015
# 8      2015
# 9      2015
# 10     2015
# 11     2015
# 12     2015
# 13     2015
# 14     2015
# 15     2015
# 16     2015
# 17     2015
# 18     2015
# 19     2015
# 20     2015
# 21     2015
# 22     2015
# 23     2015
# 24     2015
# 25     2015
# 26     2015
# 27     2015
# 28     2015
# 29     2015
#        ...
# 848    2012
# 849    2012
# 850    2012
# 851    2012
# 852    2012
# 853    2012
# 854    2012
# 855    2012
# 856    2012
# 857    2012
# 858    2012
# 859    2012
# 860    2012
# 861    2012
# 862    2012
# 863    2012
# 864    2012
# 865    2012
# 866    2012
# 867    2012
# 868    2012
# 869    2012
# 870    2012
# 871    2012
# 872    2012
# 873    2012
# 874    2012
# 875    2012
# 876    2012
# 877    2012
# Name: Date, dtype: object

# %%
new_df.head()
# Out:
#    Date       High
# 0  2015  31.629999
# 1  2015  31.290001
# 2  2015  31.860001
# 3  2015  31.840000
# 4  2015  31.750000

# %%
ax = sns.boxplot(x="Date", y="High", data=new_df)

# %%
sns.set_style('whitegrid')
ax = sns.boxplot(x = 'Date', y = 'High', date = new_df, color = '#3778bf')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-011d145a3f52> in <module>()
#       1 sns.set_style('whitegrid')
# ----> 2 ax = sns.boxplot(x = 'Date', y = 'High', date = new_df, color = '#3778bf')
#       3 ax.set_title('Distribution of stocks of AAIT over years')
#
# /Users/wuyan/anaconda/lib/python3.5/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2173     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2174                           orient, color, palette, saturation,
# -> 2175                           width, fliersize, linewidth)
#    2176
#    2177     if ax is None:
#
# ...

# %%
ax.set_title('Distribution of stocks of AAIT over years')
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)
ax.xaxis.get_label().set_fontsize(20)
ax.yaxis.get_label().set_fontsize(20)
